# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
import rdkit
import numpy as np
import pandas as pd
rdkit.__version__
# Out:
# '2023.03.3'

# %% [markdown]
# Read in the acid SMILES strings and generate descriptors for them

# %%
# Read in the acid smiles
smiles_acids = pd.read_csv("amide_smiles_substrates_acids.csv",index_col=0,header=0).index.to_list()
print(f"{len(smiles_acids)} acid SMILES read in.")
# Out:
# 66 acid SMILES read in.

# %%
# define a function for descriptor calculation
def getMolDescriptors(mol, missingVal=np.nan):
    descriptors = {}
    # calculate the descriptors
    for name,function in Descriptors._descList:
        try:
            value = function(mol)
        except:
            # assign np.nan if descriptor calculation failed
            value = missingVal
        descriptors[name] = value
    return descriptors

# %%
# calculate the descriptors
descriptors_acids = [getMolDescriptors(Chem.MolFromSmiles(smiles)) for smiles in smiles_acids]

# %%
# move to a dataframe
df_acids = pd.DataFrame(descriptors_acids, index = smiles_acids)
df_acids
# Out:
#                                   MaxAbsEStateIndex  MaxEStateIndex  \
# O=C(O)c1cc2ccccc2s1                       10.580980       10.580980
# O=C(O)c1ccco1                              9.968287        9.968287
# O=C(O)c1cccc(-c2ccccc2)c1                 10.784467       10.784467
# CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1          13.966636       13.966636
# O=C(O)C(c1ccccc1)c1ccccc1                 11.300378       11.300378
# ...                                             ...             ...
# CCCCOc1ccc(C(=O)O)cc1                     10.531775       10.531775
# O=C(O)c1ccc(-c2ccccc2)cc1                 10.648736       10.648736
# O=C(O)C1CCC(F)(F)CC1                      12.448262       12.448262
# O=C(O)c1ccncc1Cl                          10.309537       10.309537
# O=C(O)c1ccccc1                            10.200926       10.200926
#
#                                   MinAbsEStateIndex  MinEStateIndex       qed  \
# O=C(O)c1cc2ccccc2s1                        0.399259       -0.850741  0.728317
# O=C(O)c1ccco1                              0.023148       -1.032407  0.588598
# O=C(O)c1cccc(-c2ccccc2)c1                  0.316068       -0.895573  0.804747
# CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1           0.396481       -0.956610  0.893750
# O=C(O)C(c1ccccc1)c1ccccc1                  0.581111       -0.821852  0.848907
# ...                                             ...             ...       ...
# CCCCOc1ccc(C(=O)O)cc1                      0.285038       -0.911937  0.732558
# O=C(O)c1ccc(-c2ccccc2)cc1                  0.314520       -0.893878  0.804747
# O=C(O)C1CCC(F)(F)CC1                       0.113426       -2.619097  0.642153
# O=C(O)c1ccncc1Cl                           0.080247       -1.034815  0.671147
# O=C(O)c1ccccc1                             0.331019       -0.879074  0.610604
#
#                                     MolWt  HeavyAtomMolWt  ExactMolWt  \
# O=C(O)c1cc2ccccc2s1               178.212         172.164  178.008850
# O=C(O)c1ccco1                     112.084         108.052  112.016044
# O=C(O)c1cccc(-c2ccccc2)c1         198.221         188.141  198.068080
# CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1  244.265         231.161  244.089958
# O=C(O)c1ccc(-c2ccccc2)cc1                   0            0             0
# O=C(O)C1CCC(F)(F)CC1                        0            0             0
# O=C(O)c1ccncc1Cl                            0            0             0
# O=C(O)c1ccccc1                              0            0             0
#
#                                   fr_unbrch_alkane  fr_urea
# O=C(O)c1cc2ccccc2s1                              0        0
# O=C(O)c1ccco1                                    0        0
# O=C(O)c1cccc(-c2ccccc2)c1                        0        0
# CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1                 0        0
# O=C(O)C(c1ccccc1)c1ccccc1                        0        0
# ...                                            ...      ...
# CCCCOc1ccc(C(=O)O)cc1                            1        0
# O=C(O)c1ccc(-c2ccccc2)cc1                        0        0
# O=C(O)C1CCC(F)(F)CC1                             0        0
# O=C(O)c1ccncc1Cl                                 0        0
# O=C(O)c1ccccc1                                   0        0
#
# [66 rows x 209 columns]

# %%
# remove columns with nan values (meaning the descriptor calculation failed)
nan_columns = df_acids.columns[df_acids.isna().any()]
df_acids.dropna(axis=1,inplace=True)
print(f"Removed {len(nan_columns)} features with missing values: {list(nan_columns)}")
# Out:
# Removed 0 features with missing values: []

# %%
# save the data
df_acids.to_csv("./../1_Dataset_Generation/Data_For_Individual_Substrates/amide_rdkit_descr_acids.csv",
                index=True,header=True)

# %% [markdown]
# Read in the amine SMILES strings and generate descriptors for them

# %%
# Read in the amine smiles
smiles_amines = pd.read_csv("amide_smiles_substrates_amines.csv",index_col=0,header=0).index.to_list()
print(f"{len(smiles_amines)} amine SMILES read in.")
# Out:
# 70 amine SMILES read in.

# %%
# calculate the descriptors
descriptors_amines = [getMolDescriptors(Chem.MolFromSmiles(smiles)) for smiles in smiles_amines]

# %%
# move to a dataframe
df_amines = pd.DataFrame(descriptors_amines, index = smiles_amines)
df_amines
# Out:
#                                   MaxAbsEStateIndex  MaxEStateIndex  \
# Cc1ccc(N)nc1                               5.315556        5.315556
# NCc1ccc(F)cc1F                            12.530787       12.530787
# NCc1ccc(Cl)cc1                             5.627823        5.627823
# COc1ccc(CN)cc1                             5.400528        5.400528
# COc1ccc(N)cn1                              5.363316        5.363316
# ...                                             ...             ...
# CC(C)NC(C)C                                3.305556        3.305556
# Cc1ccc(S(N)(=O)=O)cc1                     10.721948       10.721948
# Nc1ccc(Cl)cn1                              5.493611        5.493611
# NCC1CC1                                    5.233796        5.233796
# Cc1cn(-c2cc(N)cc(C(F)(F)F)c2)cn1          12.588370       12.588370
#
#                                   MinAbsEStateIndex  MinEStateIndex       qed  \
# Cc1ccc(N)nc1                               0.579259        0.579259  0.537512
# NCc1ccc(F)cc1F                             0.103287       -0.581019  0.631760
# NCc1ccc(Cl)cc1                             0.580525        0.580525  0.634348
# COc1ccc(CN)cc1                             0.587296        0.587296  0.663324
# COc1ccc(N)cn1                              0.587222        0.587222  0.598238
# ...                                             ...             ...       ...
# Cc1ccc(N)nc1                                0            0             0
# NCc1ccc(F)cc1F                              0            0             0
# NCc1ccc(Cl)cc1                              0            0             0
# COc1ccc(CN)cc1                              0            0             0
# COc1ccc(N)cn1                               0            0             0
# ...                                       ...          ...           ...
# CC(C)NC(C)C                                 0            0             0
# Cc1ccc(S(N)(=O)=O)cc1                       0            0             0
# Nc1ccc(Cl)cn1                               0            0             0
# NCC1CC1                                     0            0             0
# Cc1cn(-c2cc(N)cc(C(F)(F)F)c2)cn1            0            0             0
#
#                                   fr_unbrch_alkane  fr_urea
# Cc1ccc(N)nc1                                     0        0
# NCc1ccc(F)cc1F                                   0        0
# NCc1ccc(Cl)cc1                                   0        0
# COc1ccc(CN)cc1                                   0        0
# COc1ccc(N)cn1                                    0        0
# ...                                            ...      ...
# CC(C)NC(C)C                                      0        0
# Cc1ccc(S(N)(=O)=O)cc1                            0        0
# Nc1ccc(Cl)cn1                                    0        0
# NCC1CC1                                          0        0
# Cc1cn(-c2cc(N)cc(C(F)(F)F)c2)cn1                 0        0
#
# [70 rows x 209 columns]

# %%
# remove columns with nan values (meaning the descriptor calculation failed)
nan_columns = df_amines.columns[df_amines.isna().any()]
df_amines.dropna(axis=1,inplace=True)
print(f"Removed {len(nan_columns)} features with missing values: {list(nan_columns)}")
# Out:
# Removed 0 features with missing values: []

# %%
# save the data
df_amines.to_csv("./../1_Dataset_Generation/Data_For_Individual_Substrates/amide_rdkit_descr_amines.csv",
                 index=True,header=True)

# %% [markdown]
# Read in the amide product SMILES strings and generate descriptors for them

# %%
# Read in the amine smiles
smiles_amides = pd.read_csv("amide_smiles_products.csv",index_col=0,header=0).index.to_list()
print(f"{len(smiles_amides)} amine SMILES read in.")
# Out:
# 632 amine SMILES read in.

# %%
# calculate the descriptors
descriptors_amides = [getMolDescriptors(Chem.MolFromSmiles(smiles)) for smiles in smiles_amides]

# %%
# move to a dataframe
df_amides = pd.DataFrame(descriptors_amides, index = smiles_amides)
df_amides
# Out:
#                                                MaxAbsEStateIndex  \
# Cc1ccc(NC(=O)c2cc3ccccc3s2)nc1                         12.127948
# O=C(NCc1ccc(F)cc1F)c1ccco1                             13.228583
# O=C(NCc1ccc(Cl)cc1)c1cccc(-c2ccccc2)c1                 12.331298
# COc1ccc(CNC(=O)C(C)c2ccc(-c3ccccc3)c(F)c2)cc1          14.538211
# COc1ccc(NC(=O)c2cccc(-c3ccccc3)c2)cn1                  12.381949
# ...                                                          ...
# COc1ccc(NC(=O)C2CCN(C(=O)OCc3ccccc3)CC2)cn1            12.404385
# CON(C)C(=O)c1c(C)cc(C)cc1C                             11.929587
# Cc1ccc(S(=O)(=O)NC(=O)c2ccc3nc(C)ccc3c2)cc1            12.300494
# Cc1ccc(Cl)c(NC(=O)c2ccc3nccnc3c2)c1                    12.303349
# O=C(Cc1ccc2c(c1)OCO2)Nc1ccc(Cl)cn1                     11.910805
# COc1ccc(CNC(=O)C(C)c2ccc(-c3ccccc3)c(F)c2)cc1             0            0
# COc1ccc(NC(=O)c2cccc(-c3ccccc3)c2)cn1                     0            0
# ...                                                     ...          ...
# COc1ccc(NC(=O)C2CCN(C(=O)OCc3ccccc3)CC2)cn1               0            0
# CON(C)C(=O)c1c(C)cc(C)cc1C                                0            0
# Cc1ccc(S(=O)(=O)NC(=O)c2ccc3nc(C)ccc3c2)cc1               0            0
# Cc1ccc(Cl)c(NC(=O)c2ccc3nccnc3c2)c1                       0            0
# O=C(Cc1ccc2c(c1)OCO2)Nc1ccc(Cl)cn1                        0            0
#
#                                                fr_thiocyan  fr_thiophene  \
# Cc1ccc(NC(=O)c2cc3ccccc3s2)nc1                           0             1
# O=C(NCc1ccc(F)cc1F)c1ccco1                               0             0
# O=C(NCc1ccc(Cl)cc1)c1cccc(-c2ccccc2)c1                   0             0
# COc1ccc(CNC(=O)C(C)c2ccc(-c3ccccc3)c(F)c2)cc1            0             0
# COc1ccc(NC(=O)c2cccc(-c3ccccc3)c2)cn1                    0             0
# ...                                                    ...           ...
# COc1ccc(NC(=O)C2CCN(C(=O)OCc3ccccc3)CC2)cn1              0             0
# CON(C)C(=O)c1c(C)cc(C)cc1C                               0             0
# Cc1ccc(S(=O)(=O)NC(=O)c2ccc3nc(C)ccc3c2)cc1              0             0
# Cc1ccc(Cl)c(NC(=O)c2ccc3nccnc3c2)c1                      0             0
# O=C(Cc1ccc2c(c1)OCO2)Nc1ccc(Cl)cn1                       0             0
#
#                                                fr_unbrch_alkane  fr_urea
# Cc1ccc(NC(=O)c2cc3ccccc3s2)nc1                                0        0
# O=C(NCc1ccc(F)cc1F)c1ccco1                                    0        0
# O=C(NCc1ccc(Cl)cc1)c1cccc(-c2ccccc2)c1                        0        0
# COc1ccc(CNC(=O)C(C)c2ccc(-c3ccccc3)c(F)c2)cc1                 0        0
# COc1ccc(NC(=O)c2cccc(-c3ccccc3)c2)cn1                         0        0
# ...                                                         ...      ...
# COc1ccc(NC(=O)C2CCN(C(=O)OCc3ccccc3)CC2)cn1                   0        0
# CON(C)C(=O)c1c(C)cc(C)cc1C                                    0        0
# Cc1ccc(S(=O)(=O)NC(=O)c2ccc3nc(C)ccc3c2)cc1                   0        0
# Cc1ccc(Cl)c(NC(=O)c2ccc3nccnc3c2)c1                           0        0
# O=C(Cc1ccc2c(c1)OCO2)Nc1ccc(Cl)cn1                            0        0
#
# [632 rows x 209 columns]

# %%
# remove columns with nan values (meaning the descriptor calculation failed)
nan_columns = df_amides.columns[df_amides.isna().any()]
df_amides.dropna(axis=1,inplace=True)
print(f"Removed {len(nan_columns)} features with missing values: {list(nan_columns)}")
# Out:
# Removed 0 features with missing values: []

# %%
# save the data
df_amides.to_csv("./../1_Dataset_Generation/Data_For_Individual_Substrates/amide_rdkit_descr_prods.csv",index=True,header=True)
