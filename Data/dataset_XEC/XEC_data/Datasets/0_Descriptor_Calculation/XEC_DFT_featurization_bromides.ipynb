# %% [markdown]
# ### Use the published autochem workflow to generate DFT features for the compounds in the dataset

# %% [markdown]
# NOTE: This notebook needs to be run with the python environment for autoqchem.

# %%
from autoqchem.molecule import molecule
from autoqchem.sge_manager import sge_manager
from autoqchem.draw_utils import draw
from autoqchem.db_functions import descriptors
from rdkit import Chem
import pandas as pd
import numpy as np
import logging
logging.basicConfig(level=logging.INFO)

# %%
# connect to UCLA's computation cluster
sm = sge_manager(user='XXXX', host='hoffman2.idre.ucla.edu')
sm.connect()

# %% [markdown]
# ### Load the product smiles strings and create input files for the DFT calculations

# %%
# Load the previously saved list of reaction products
df_bromides = pd.read_csv("./xec_smiles_bromide_scope.csv",names=["SMILES"])
df_bromides
# Out:
#                                    SMILES
# 0    C[C@@H](NC(=O)OC(C)(C)C)c1ccc(Br)cc1
# 1                  CCOC(=O)c1nnc(Br)[nH]1
# 2          O=C(c1cc2cc(Br)cnc2s1)N1CCOCC1
# 3                            COc1ccccc1Br
# 4                             Cc1ccccc1Br
# ..                                    ...
# 376             Brc1ccc([C@@H]2CNCCO2)cc1
# 377       FC(F)(F)c1ccnc(Nc2cccc(Br)c2)n1
# 378             CC1(C)Cc2cc(Cl)cc(Br)c2O1
# 379       Cc1cc(Br)cc(Nc2nccc(C3CC3)n2)c1
# 380          O=S(=O)(Nc1ccccc1Br)C(F)(F)F
#
# [381 rows x 1 columns]

# %%
bromide_smiles = df_bromides["SMILES"].to_list()
print(f"Total number of substrates: {len(bromide_smiles)}")
# Out:
# Total number of substrates: 381

# %%
# generate molecule objects with up to 3 conformers for each structure
mols = [molecule(s, num_conf=3) for s in bromide_smiles]
# Out:
# [23:07:51] WARNING: Charges were rearranged

# %%
# check the compounds by drawing them
draw(mols[33].mol)
# Out:
# interactive(children=(Dropdown(description='confId', options=(0, 1), value=0), Output()), _dom_classes=('widge…
# <function autoqchem.draw_utils._graph_conf(m, confId=0, energies=[])>

# %%
# create Gaussian jobs locally
for mol in mols:
    sm.create_jobs_for_molecule(mol, theory="APFD",heavy_basis_set="LANL2DZ",light_basis_set='6-31G*',max_light_atomic_number=36)
# Out:
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C6H4BrN3/c7-5-3-9-6-8-1-2-10(6)4-5/h1-4H already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C4H2BrNO2S/c5-2-1-9-3(6-2)4(7)8/h1H,(H,7,8) already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C8H3BrF3NS/c9-4-1-2-5-6(3-4)14-7(13-5)8(10,11)12/h1-3H already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C9H5BrO3/c10-5-1-2-6-7(11)4-9(12)13-8(6)3-5/h1-4,11H already exists with the same Gaussian config with tags ['ArBr_NiAr_WCG']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C7H3BrClNO/c8-4-1-2-6-5(3-4)7(9)10-11-6/h1-3H already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C9H7BrN2O2/c1-14-9(13)5-2-6-7(10)4-12-8(6)11-3-5/h2-4H,1H3,(H,11,12) already exists with the same Gaussian config with tags ['ArBr_NiAr_WCG']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C16H22BrNO2/c1-16(2,3)20-15(19)18-11-5-4-6-14(18)12-7-9-13(17)10-8-12/h7-10,14H,4-6,11H2,1-3H3/t14-/m1/s1 already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C10H5BrF3N/c11-8-2-1-6-4-9(10(12,13)14)15-5-7(6)3-8/h1-5H already exists with the same Gaussian config with tags ['ArBr_NiAr_WCG']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C8H7BrN2O/c9-5-3-7-6(10-4-5)1-2-8(12)11-7/h3-4H,1-2H2,(H,11,12) already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# WARNING:autoqchem.sge_manager:Molecule InChI=1S/C8H6BrFN2/c1-5-3-12-4-6(10)2-7(9)8(12)11-5/h2-4H,1H3 already exists with the same Gaussian config with tags ['arylbromides_ssg']. Not creating jobs.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 1 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 2 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.
# INFO:autoqchem.gaussian_input_generator:Generating Gaussian input files for 3 conformations.

# %% [markdown]
# Note how 10 compounds were already calculated with the same parameters in other datasets and therefore not recalculated.

# %% [markdown]
# ### Manage the DFT jobs on the cluster

# %%
# Submit jobs
sm.submit_jobs()
# Out:
# INFO:autoqchem.sge_manager:Submitting 27 jobs.
#   0%|          | 0/27 [00:00<?, ?it/s]INFO:autoqchem.sge_manager:Submitted job 3d30411824927e811c05cb5626a838f3, job_id: 10345980.
#   4%|▎         | 1/27 [00:01<00:50,  1.93s/it]INFO:autoqchem.sge_manager:Submitted job 2e504a805b00190a3ab5fdfda85f1f85, job_id: 10345981.
#   7%|▋         | 2/27 [00:03<00:42,  1.69s/it]INFO:autoqchem.sge_manager:Submitted job 3fcc6d5fc435923088ca8851a336691e, job_id: 10345982.
#  11%|█         | 3/27 [00:04<00:38,  1.62s/it]INFO:autoqchem.sge_manager:Submitted job f06f803388e93d4a02e78bf31bdab917, job_id: 10345983.
#  15%|█▍        | 4/27 [00:06<00:36,  1.59s/it]INFO:autoqchem.sge_manager:Submitted job ac92c560c3c110961ed26f4cefc47066, job_id: 10345984.
#  19%|█▊        | 5/27 [00:08<00:35,  1.61s/it]INFO:autoqchem.sge_manager:Submitted job 4c3dd87e34bfd9cef85de420c2364968, job_id: 10345985.
#  22%|██▏       | 6/27 [00:09<00:33,  1.59s/it]INFO:autoqchem.sge_manager:Submitted job c4c6fa4eb39c31e212be7ee1a7cc163a, job_id: 10345986.
#  26%|██▌       | 7/27 [00:11<00:31,  1.56s/it]INFO:autoqchem.sge_manager:Submitted job 4b388b811574ee27b7ea540a264bd9a4, job_id: 10345987.
#  93%|█████████▎| 25/27 [00:38<00:03,  1.57s/it]INFO:autoqchem.sge_manager:Submitted job 74e3284c1564695ae225dee7abc789d7, job_id: 10346005.
#  96%|█████████▋| 26/27 [00:39<00:01,  1.53s/it]INFO:autoqchem.sge_manager:Submitted job a05bc7b53de33891d35d7f8ed066ddc2, job_id: 10346006.
# 100%|██████████| 27/27 [00:41<00:00,  1.53s/it]

# %%
# Resubmit jobs that did not finish properly
sm.resubmit_incomplete_jobs()
# Out:
# INFO:autoqchem.sge_manager:There are no incomplete jobs to resubmit.

# %%
# Retrieve finished jobs from the cluster
sm.retrieve_jobs()
# Out:
# INFO:autoqchem.sge_manager:There are no jobs submitted to cluster. Nothing to retrieve.

# %%
# Upload data for finished compounds to the autoqchem database (autoqchem.org)
sm.upload_done_molecules_to_db(tags=["SVR_MacMillanXEC_ArBr"])

# %% [markdown]
# ### Get the desriptors from the autoqchem database

# %%
# Download the descriptors
data = descriptors(tags=["SVR_MacMillanXEC_ArBr"],presets=["global","substructure"],conf_option="boltzmann",solvent="None",
                   functional="APFD",basis_set="6-31G*",substructure="cBr")

# %%
# Process the data so that it is in one dataframe
label_dict={}
for key in data:
    if key != "global":
        # atom descriptor dataframes are by default called atom1, atom2, etc. --> replace with the atom type and a running number (e. g. "C1" and "C2")
        if data[key].iloc[0,-1] not in label_dict:
            label_dict[data[key].iloc[0,-1]] = 1
        else:
            label_dict[data[key].iloc[0,-1]] += 1
        label = data[key].iloc[0,-1]+str(label_dict[data[key].iloc[0,-1]])
        data[key].drop(columns=["labels","X","Y","Z"],inplace=True)
        data[key].columns = [f"{label}_{column}" for column in data[key].columns]
    else:
        data[key].drop(columns=["converged","multiplicity"],inplace=True)

df_combined = pd.concat(data,axis=1)
df_combined.columns = [multi_column_index[1] for multi_column_index in df_combined.columns]

# %%
df_combined
# Out:
#                                              E  ES_root_dipole  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O         -3231.540851          3.5075
# B(c1ccc(s1)Br)(O)O                -3299.457693          2.1397
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br -3213.049261          2.2397
# C#Cc1ccc(cc1)Br                   -2878.927637          1.4534
# C#Cc1ccccc1Br                     -2878.926724          0.8340
# ...                                        ...             ...
# c1csc(c1C(=O)O)Br                 -3312.017336          3.4126
# c1csc(n1)Br                       -3139.649215          3.9538
# c1nc([nH]n1)Br                    -2812.903766          3.7585
# c1nnc(s1)Br                       -3155.667110          1.4351
# n1cscc1Br                         -3139.649994          2.9130
#
#                                    ES_root_electronic_spatial_extent  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O                                 3630.15185
# B(c1ccc(s1)Br)(O)O                                        2593.08990
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br                         7563.16400
# C#Cc1ccc(cc1)Br                                           2237.10170
# C#Cc1ccccc1Br                                             1653.06000
# ...                                                              ...
# c1csc(c1C(=O)O)Br                                         1857.40080
# c1csc(n1)Br                                               1052.24420
# c1nc([nH]n1)Br                                             853.33380
# c1nnc(s1)Br                                               1026.02200
# n1cscc1Br                                                 1160.42730
#
#                                    ES_root_molar_volume        E_scf  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O                   1726.752875 -3231.628761
# B(c1ccc(s1)Br)(O)O                          1126.156000 -3299.402577
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br           1709.256000 -3213.247530
# C#Cc1ccc(cc1)Br                             1121.382000 -2879.035644
# C#Cc1ccccc1Br                               1126.144000 -2879.033831
# ...                                                 ...          ...
# c1csc(c1C(=O)O)Br                           1201.187000 -3312.094419
# c1csc(n1)Br                                  939.031000 -3139.698151
# c1nc([nH]n1)Br                               910.640000 -2812.957389
# c1nnc(s1)Br                                  703.107000 -3155.703156
# n1cscc1Br                                    679.615000 -3139.699929
#
#                                    E_thermal_correction        E_zpe  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O                      0.183063 -3231.554710
# B(c1ccc(s1)Br)(O)O                             0.091292 -3299.466757
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br              0.280880 -3213.064991
# C#Cc1ccc(cc1)Br                                0.108007 -2878.935466
# C#Cc1ccccc1Br                                  0.108103 -2878.934485
# ...                                                 ...          ...
# c1csc(c1C(=O)O)Br                              0.080964 -3312.025510
# c1csc(n1)Br                                    0.050962 -3139.654401
# c1nc([nH]n1)Br                                 0.055401 -2812.908491
# c1nnc(s1)Br                                    0.038571 -3155.672146
# n1cscc1Br                                      0.050946 -3139.655154
#
#                                              G  G_thermal_correction  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O         -3231.596811              0.127104
# B(c1ccc(s1)Br)(O)O                -3299.503329              0.045656
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br -3213.108849              0.221291
# C#Cc1ccc(cc1)Br                   -2878.968515              0.067129
# C#Cc1ccccc1Br                     -2878.968033              0.066794
# ...                                        ...                   ...
# c1csc(c1C(=O)O)Br                 -3312.060534              0.037766
# c1csc(n1)Br                       -3139.684950              0.015227
# c1nc([nH]n1)Br                    -2812.938133              0.021035
# c1nnc(s1)Br                       -3155.702621              0.003060
# n1cscc1Br                         -3139.685695              0.015245
#
#                                              H  ...  Br1_ES_root_NPA_valence  \
# can                                             ...
# B(c1c(ccc(c1Br)OCC)F)(O)O         -3231.539907  ...                 6.815777
# B(c1ccc(s1)Br)(O)O                -3299.456749  ...                  6.68514
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br -3213.048316  ...                  6.85791
# C#Cc1ccc(cc1)Br                   -2878.926693  ...                  6.83711
# C#Cc1ccccc1Br                     -2878.925780  ...                  6.72542
# ...                                        ...  ...                      ...
# c1csc(c1C(=O)O)Br                 -3312.016392  ...                  6.66052
# c1csc(n1)Br                       -3139.648271  ...                  6.82329
# c1nc([nH]n1)Br                    -2812.902822  ...                  6.91168
# c1nnc(s1)Br                       -3155.666166  ...                  6.81651
# n1cscc1Br                         -3139.649049  ...                  6.60137
#
#                                    Br1_Mulliken_charge  Br1_NMR_anisotropy  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O                    -0.086074          765.158775
# B(c1ccc(s1)Br)(O)O                           -0.044191            948.7559
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br            -0.110674           1074.2565
# C#Cc1ccc(cc1)Br                              -0.100266           1065.2392
# C#Cc1ccccc1Br                                -0.085612            986.9976
# ...                                                ...                 ...
# c1csc(c1C(=O)O)Br                            -0.005087             836.567
# c1csc(n1)Br                                  -0.022554            1211.569
# c1nc([nH]n1)Br                               -0.033335            986.5422
# c1nnc(s1)Br                                   0.007124           1050.1952
# n1cscc1Br                                    -0.064025           1082.4151
#
#                                    Br1_NMR_shift  Br1_NPA_Rydberg  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O            2312.589798          0.01855
# B(c1ccc(s1)Br)(O)O                     2269.7402          0.02098
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br      2216.7303          0.01778
# C#Cc1ccc(cc1)Br                        2212.6936          0.01802
# C#Cc1ccccc1Br                          2225.2734          0.01801
# ...                                          ...              ...
# c1csc(c1C(=O)O)Br                      2217.0024          0.02115
# c1csc(n1)Br                             2111.428          0.02067
# c1nc([nH]n1)Br                         2300.4773          0.02045
# c1nnc(s1)Br                            2186.8076          0.02119
# n1cscc1Br                              2239.8811           0.0196
#
#                                    Br1_NPA_charge  Br1_NPA_core  \
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O                0.084334     27.999009
# B(c1ccc(s1)Br)(O)O                        0.13192      27.99896
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br         0.06333      27.99911
# C#Cc1ccc(cc1)Br                           0.07411       27.9991
# C#Cc1ccccc1Br                             0.09159      27.99906
# ...                                           ...           ...
# c1csc(c1C(=O)O)Br                         0.16721      27.99893
# c1csc(n1)Br                               0.13306      27.99894
# c1nc([nH]n1)Br                            0.12789      27.99892
# c1nnc(s1)Br                               0.16269       27.9989
# n1cscc1Br                                 0.10187      27.99901
#
#                                    Br1_NPA_total  Br1_NPA_valence  Br1_VBur
# can
# B(c1c(ccc(c1Br)OCC)F)(O)O              34.915666         6.898106  0.475556
# B(c1ccc(s1)Br)(O)O                      34.86808          6.84814  0.369651
# B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)Br       34.93667          6.91978  0.374921
# C#Cc1ccc(cc1)Br                         34.92589          6.90878  0.375393
# C#Cc1ccccc1Br                           34.90841          6.89133  0.402297
# ...                                          ...              ...       ...
# c1csc(c1C(=O)O)Br                       34.83279          6.81272   0.40686
# c1csc(n1)Br                             34.86694          6.84732  0.363436
# c1nc([nH]n1)Br                          34.87211          6.85274  0.356199
# c1nnc(s1)Br                             34.83731          6.81722  0.363279
# n1cscc1Br                               34.89813          6.87952  0.362807
#
# [371 rows x 54 columns]

# %% [markdown]
# Get the missing compounds from the other datasets.

# %%
# canonicalize the smiles
df_combined.index = [Chem.MolToSmiles(Chem.MolFromSmiles(s)) for s in df_combined.index]

# look for missing bromides
missing_bromides = []
for bromide in bromide_smiles:
    if bromide not in df_combined.index:
        if bromide != Chem.MolToSmiles(Chem.MolFromSmiles('[2H]c1nc(cs1)Br')):
            # manually remove this one smiles from the list as it gave errors in the descriptor calculations due to the isotope
            # this smiles was manually changed to the smiles "n1cscc1Br" or the autoqchem calculations
            # this is the protiated version of the original deuterium-labelled compond. It was assumed that the 
            # isotope will have a negligible effect on the reactivity.
            missing_bromides.append(bromide)
print(f"There are {len(missing_bromides)} missing bromides.")
# Out:
# There are 10 missing bromides.

# %%
other_dsets = ["arylbromides_ssg","ArBr_NiAr_WCG"]
missing_bromides = [Chem.MolToSmiles(Chem.MolFromSmiles(bromide),canonical=True) for bromide in missing_bromides]
dfs_missing = {}
for dset in other_dsets:
# Download the descriptors from the other datasets
    data_missing = descriptors(tags=[dset],presets=["global","substructure"],conf_option="boltzmann",solvent="None",
                    functional="APFD",basis_set="6-31G*",substructure="cBr")
    # Process the data so that it is in one dataframe
    label_dict={}
    for key in data:
        if key != "global":
            # atom descriptor dataframes are by default called atom1, atom2, etc. --> replace with the atom type and a running number (e. g. "C1" and "C2")
            if data_missing[key].iloc[0,-1] not in label_dict:
                label_dict[data_missing[key].iloc[0,-1]] = 1
            else:
                label_dict[data_missing[key].iloc[0,-1]] += 1
            label = data_missing[key].iloc[0,-1]+str(label_dict[data_missing[key].iloc[0,-1]])
            data_missing[key].drop(columns=["labels","X","Y","Z"],inplace=True)
            data_missing[key].columns = [f"{label}_{column}" for column in data_missing[key].columns]
        else:
            data_missing[key].drop(columns=["converged","multiplicity"],inplace=True)

    df_missing = pd.concat(data_missing,axis=1)
    df_missing.columns = [multi_column_index[1] for multi_column_index in df_missing.columns]
    df_missing.index = [Chem.MolToSmiles(Chem.MolFromSmiles(smiles),canonical=True) for smiles in df_missing.index]
    df_missing = df_missing.loc[df_missing.index.isin(missing_bromides)]
    dfs_missing[dset] = df_missing
df_missing = pd.concat(dfs_missing,axis=0)
df_missing.index = [multi_index[1] for multi_index in df_missing.index]
df_missing
# Out:
#                                               E  ES_root_dipole  \
# Brc1cnc2nccn2c1                    -2966.365637        4.894800
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1 -3398.669046        3.184877
# Cc1cn2cc(F)cc(Br)c2n1              -3088.759492        4.768500
# Clc1noc2ccc(Br)cc12                -3429.649744        5.670200
# FC(F)(F)c1nc2ccc(Br)cc2s1          -3629.928558        4.814900
# O=C1CCc2ncc(Br)cc2N1               -3064.781081        0.821700
# O=C(O)c1nc(Br)cs1                  -3328.063391        0.967800
# COC(=O)c1cnc2[nH]cc(Br)c2c1        -3178.002918        8.554152
# FC(F)(F)c1cc2ccc(Br)cc2cn1         -3309.171551        5.377200
# O=c1cc(O)c2ccc(Br)cc2o1            -3142.569127        3.789804
#
#                                     ES_root_electronic_spatial_extent  \
# Brc1cnc2nccn2c1                                           2244.333000
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1                       10137.509207
# Cc1cn2cc(F)cc(Br)c2n1                                     2910.936000
# Clc1noc2ccc(Br)cc12                                       3247.597500
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1       34.94234         6.925384  0.376253
# Cc1cn2cc(F)cc(Br)c2n1                    34.87277          6.85467  0.385935
# Clc1noc2ccc(Br)cc12                      34.91694          6.89973  0.377124
# FC(F)(F)c1nc2ccc(Br)cc2s1                34.91505          6.89783  0.377911
# O=C1CCc2ncc(Br)cc2N1                     34.91666          6.89923  0.374685
# O=C(O)c1nc(Br)cs1                         34.8808          6.86212  0.363436
# COC(=O)c1cnc2[nH]cc(Br)c2c1              34.90218          6.88344  0.373893
# FC(F)(F)c1cc2ccc(Br)cc2cn1               34.91359          6.89648  0.377281
# O=c1cc(O)c2ccc(Br)cc2o1                 34.909917         6.892745  0.376964
#
# [10 rows x 54 columns]

# %%
#combine the data to get the final dataset
df_combined = pd.concat([df_combined,df_missing],axis=0)
df_combined
# Out:
#                                          E  ES_root_dipole  \
# CCOc1ccc(F)c(B(O)O)c1Br       -3231.540851        3.507500
# OB(O)c1ccc(Br)s1              -3299.457693        2.139700
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C -3213.049261        2.239700
# C#Cc1ccc(Br)cc1               -2878.927637        1.453400
# C#Cc1ccccc1Br                 -2878.926724        0.834000
# ...                                    ...             ...
# O=C1CCc2ncc(Br)cc2N1          -3064.781081        0.821700
# O=C(O)c1nc(Br)cs1             -3328.063391        0.967800
# COC(=O)c1cnc2[nH]cc(Br)c2c1   -3178.002918        8.554152
# FC(F)(F)c1cc2ccc(Br)cc2cn1    -3309.171551        5.377200
# O=c1cc(O)c2ccc(Br)cc2o1       -3142.569127        3.789804
#
#                                ES_root_electronic_spatial_extent  \
# CCOc1ccc(F)c(B(O)O)c1Br                              3630.151850
# OB(O)c1ccc(Br)s1                                     2593.089900
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                        7563.164000
# C#Cc1ccc(Br)cc1                                      2237.101700
# C#Cc1ccccc1Br                                        1653.060000
# ...                                                          ...
# O=C1CCc2ncc(Br)cc2N1                                 3543.239600
# O=C(O)c1nc(Br)cs1                                    2296.703700
# COC(=O)c1cnc2[nH]cc(Br)c2c1                          4494.894471
# FC(F)(F)c1cc2ccc(Br)cc2cn1                           6034.508600
# O=c1cc(O)c2ccc(Br)cc2o1                              3896.268543
#
#                                ES_root_molar_volume        E_scf  \
# CCOc1ccc(F)c(B(O)O)c1Br                 1726.752875 -3231.628761
# OB(O)c1ccc(Br)s1                        1126.156000 -3299.402577
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C           1709.256000 -3213.247530
# C#Cc1ccc(Br)cc1                         1121.382000 -2879.035644
# C#Cc1ccccc1Br                           1126.144000 -2879.033831
# ...                                             ...          ...
# O=C1CCc2ncc(Br)cc2N1                    1386.651000 -3064.930211
# O=C(O)c1nc(Br)cs1                        846.744000 -3328.127785
# COC(=O)c1cnc2[nH]cc(Br)c2c1             1656.668248 -3178.163254
# FC(F)(F)c1cc2ccc(Br)cc2cn1              1944.921000 -3309.305128
# O=c1cc(O)c2ccc(Br)cc2o1                 1433.087856 -3142.695844
# O=C(O)c1nc(Br)cs1                       1099.5199      2223.5756
# COC(=O)c1cnc2[nH]cc(Br)c2c1            735.527369    2485.693371
# FC(F)(F)c1cc2ccc(Br)cc2cn1              1087.1564      2201.6786
# O=c1cc(O)c2ccc(Br)cc2o1               1070.058017    2191.142049
#
#                                Br1_NPA_Rydberg  Br1_NPA_charge  Br1_NPA_core  \
# CCOc1ccc(F)c(B(O)O)c1Br                0.01855        0.084334     27.999009
# OB(O)c1ccc(Br)s1                       0.02098         0.13192      27.99896
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C          0.01778         0.06333      27.99911
# C#Cc1ccc(Br)cc1                        0.01802         0.07411       27.9991
# C#Cc1ccccc1Br                          0.01801         0.09159      27.99906
# ...                                        ...             ...           ...
# O=C1CCc2ncc(Br)cc2N1                   0.01833         0.08334      27.99909
# O=C(O)c1nc(Br)cs1                      0.01968          0.1192        27.999
# COC(=O)c1cnc2[nH]cc(Br)c2c1           0.019735         0.09782        27.999
# FC(F)(F)c1cc2ccc(Br)cc2cn1             0.01802         0.08641      27.99909
# O=c1cc(O)c2ccc(Br)cc2o1               0.018092        0.090083      27.99909
#
#                                Br1_NPA_total  Br1_NPA_valence  Br1_VBur
# CCOc1ccc(F)c(B(O)O)c1Br            34.915666         6.898106  0.475556
# OB(O)c1ccc(Br)s1                    34.86808          6.84814  0.369651
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C       34.93667          6.91978  0.374921
# C#Cc1ccc(Br)cc1                     34.92589          6.90878  0.375393
# C#Cc1ccccc1Br                       34.90841          6.89133  0.402297
# ...                                      ...              ...       ...
# O=C1CCc2ncc(Br)cc2N1                34.91666          6.89923  0.374685
# O=C(O)c1nc(Br)cs1                    34.8808          6.86212  0.363436
# COC(=O)c1cnc2[nH]cc(Br)c2c1         34.90218          6.88344  0.373893
# FC(F)(F)c1cc2ccc(Br)cc2cn1          34.91359          6.89648  0.377281
# O=c1cc(O)c2ccc(Br)cc2o1            34.909917         6.892745  0.376964
#
# [381 rows x 54 columns]

# %%
def feature_preprocessing(df):
    """
    Function for removing non-varied and highly correlated features.
    Take a df as input and returns it in processed form.
    """
    # Remove columns that have only one or two unique values.
    removed_columns = []
    for column in df.columns:
        if len(np.unique(df[column].values)) <= 2:
            removed_columns.append(column)
    df = df.drop(removed_columns, axis=1)
    
    # Remove highly correlated features
    corr_matrix = df.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
    df = df.drop(to_drop, axis=1)

    # Store the names of the column removed due to correlation
    for column in to_drop:
        removed_columns.append(column)

    print(f"The following features were removed: {removed_columns}")
    
    return df

df_processed = feature_preprocessing(df_combined)
df_processed
# Out:
# The following features were removed: ['charge', 'E_scf', 'E_zpe', 'G', 'G_thermal_correction', 'H', 'H_thermal_correction', 'electronic_spatial_extent', 'number_of_atoms', 'zero_point_correction', 'C1_ES_root_NPA_total', 'C1_ES_root_NPA_valence', 'C1_Mulliken_charge', 'C1_NPA_core', 'C1_NPA_total', 'C1_NPA_valence', 'Br1_ES_root_NPA_charge', 'Br1_ES_root_NPA_total', 'Br1_ES_root_NPA_valence', 'Br1_NPA_total', 'Br1_NPA_valence']
#                                          E  ES_root_dipole  \
# CCOc1ccc(F)c(B(O)O)c1Br       -3231.540851        3.507500
# OB(O)c1ccc(Br)s1              -3299.457693        2.139700
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C -3213.049261        2.239700
# C#Cc1ccc(Br)cc1               -2878.927637        1.453400
# C#Cc1ccccc1Br                 -2878.926724        0.834000
# ...                                    ...             ...
# O=C1CCc2ncc(Br)cc2N1          -3064.781081        0.821700
# O=C(O)c1nc(Br)cs1             -3328.063391        0.967800
# COC(=O)c1cnc2[nH]cc(Br)c2c1   -3178.002918        8.554152
# FC(F)(F)c1cc2ccc(Br)cc2cn1    -3309.171551        5.377200
# O=c1cc(O)c2ccc(Br)cc2o1       -3142.569127        3.789804
#
#                                ES_root_electronic_spatial_extent  \
# CCOc1ccc(F)c(B(O)O)c1Br                              3630.151850
# OB(O)c1ccc(Br)s1                                     2593.089900
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                        7563.164000
# C#Cc1ccc(Br)cc1                                      2237.101700
# C#Cc1ccccc1Br                                        1653.060000
# ...                                                          ...
# O=C1CCc2ncc(Br)cc2N1                                 3543.239600
# O=C(O)c1nc(Br)cs1                                    2296.703700
# COC(=O)c1cnc2[nH]cc(Br)c2c1                          4494.894471
# FC(F)(F)c1cc2ccc(Br)cc2cn1                           6034.508600
# O=c1cc(O)c2ccc(Br)cc2o1                              3896.268543
#
#                                ES_root_molar_volume  E_thermal_correction  \
# CCOc1ccc(F)c(B(O)O)c1Br                 1726.752875              0.183063
# OB(O)c1ccc(Br)s1                        1126.156000              0.091292
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C           1709.256000              0.280880
# C#Cc1ccc(Br)cc1                         1121.382000              0.108007
# C#Cc1ccccc1Br                           1126.144000              0.108103
# ...                                             ...                   ...
# O=C1CCc2ncc(Br)cc2N1                    1386.651000              0.152538
# O=C(O)c1nc(Br)cs1                        846.744000              0.068971
# COC(=O)c1cnc2[nH]cc(Br)c2c1             1656.668248              0.164616
# FC(F)(F)c1cc2ccc(Br)cc2cn1              1944.921000              0.143300
# O=c1cc(O)c2ccc(Br)cc2o1                 1433.087856              0.133261
#
#                                  dipole  electronegativity  hardness  \
# CCOc1ccc(F)c(B(O)O)c1Br        2.352038           0.141368  0.104404
# OB(O)c1ccc(Br)s1               1.166600           0.140780  0.100210
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C  2.232500           0.137680  0.107840
# C#Cc1ccc(Br)cc1                1.189900           0.140565  0.100035
# C#Cc1ccccc1Br                  1.776500           0.141540  0.102190
# ...                                 ...                ...       ...
# O=C1CCc2ncc(Br)cc2N1           1.004500           0.141895  0.101565
# O=C(O)c1nc(Br)cs1              4.374300           0.181120  0.093130
# COC(=O)c1cnc2[nH]cc(Br)c2c1    2.466699           0.140353  0.092141
# FC(F)(F)c1cc2ccc(Br)cc2cn1     3.817300           0.165160  0.090360
# O=c1cc(O)c2ccc(Br)cc2o1        4.459878           0.156745  0.090172
#
#                                homo_energy  lumo_energy  ...  \
# CCOc1ccc(F)c(B(O)O)c1Br          -0.245772    -0.036964  ...
# OB(O)c1ccc(Br)s1                 -0.240990    -0.040570  ...
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C    -0.245520    -0.029840  ...
# C#Cc1ccc(Br)cc1                  -0.240600    -0.040530  ...
# C#Cc1ccccc1Br                    -0.243730    -0.039350  ...
# ...                                    ...          ...  ...
# O=C1CCc2ncc(Br)cc2N1             -0.243460    -0.040330  ...
# O=C(O)c1nc(Br)cs1                -0.274250    -0.087990  ...
# COC(=O)c1cnc2[nH]cc(Br)c2c1      -0.232493    -0.048212  ...
# FC(F)(F)c1cc2ccc(Br)cc2cn1       -0.255520    -0.074800  ...
# O=c1cc(O)c2ccc(Br)cc2o1          -0.246917    -0.066573  ...
#
#                                Br1_ES_root_Mulliken_charge  \
# CCOc1ccc(F)c(B(O)O)c1Br                          -0.021834
# OB(O)c1ccc(Br)s1                                  0.086668
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                    -0.059843
# C#Cc1ccc(Br)cc1                                   -0.04278
# C#Cc1ccccc1Br                                     0.054455
# ...                                                    ...
# O=C1CCc2ncc(Br)cc2N1                              -0.06787
# O=C(O)c1nc(Br)cs1                                -0.070642
# COC(=O)c1cnc2[nH]cc(Br)c2c1                       0.091154
# FC(F)(F)c1cc2ccc(Br)cc2cn1                        0.031004
# O=c1cc(O)c2ccc(Br)cc2o1                          -0.059339
#
#                                Br1_ES_root_NPA_Rydberg Br1_ES_root_NPA_core  \
# CCOc1ccc(F)c(B(O)O)c1Br                       0.020462            27.998934
# OB(O)c1ccc(Br)s1                               0.02459             27.99881
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                  0.01919             27.99905
# C#Cc1ccc(Br)cc1                                0.01881             27.99902
# C#Cc1ccccc1Br                                  0.01891             27.99889
# ...                                                ...                  ...
# O=C1CCc2ncc(Br)cc2N1                           0.01989             27.99903
# O=C(O)c1nc(Br)cs1                               0.0198             27.99898
# COC(=O)c1cnc2[nH]cc(Br)c2c1                   0.018729            27.998885
# FC(F)(F)c1cc2ccc(Br)cc2cn1                     0.01792             27.99897
# O=c1cc(O)c2ccc(Br)cc2o1                       0.019713             27.99905
#
#                               Br1_Mulliken_charge Br1_NMR_anisotropy  \
# CCOc1ccc(F)c(B(O)O)c1Br                 -0.086074         765.158775
# OB(O)c1ccc(Br)s1                        -0.044191           948.7559
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C           -0.110674          1074.2565
# C#Cc1ccc(Br)cc1                         -0.100266          1065.2392
# C#Cc1ccccc1Br                           -0.085612           986.9976
# ...                                           ...                ...
# O=C1CCc2ncc(Br)cc2N1                    -0.090537          1000.2284
# O=C(O)c1nc(Br)cs1                        -0.04506          1099.5199
# COC(=O)c1cnc2[nH]cc(Br)c2c1             -0.092303         735.527369
# FC(F)(F)c1cc2ccc(Br)cc2cn1              -0.084894          1087.1564
# O=c1cc(O)c2ccc(Br)cc2o1                 -0.082459        1070.058017
#
#                               Br1_NMR_shift Br1_NPA_Rydberg Br1_NPA_charge  \
# CCOc1ccc(F)c(B(O)O)c1Br         2312.589798         0.01855       0.084334
# OB(O)c1ccc(Br)s1                  2269.7402         0.02098        0.13192
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C     2216.7303         0.01778        0.06333
# C#Cc1ccc(Br)cc1                   2212.6936         0.01802        0.07411
# C#Cc1ccccc1Br                     2225.2734         0.01801        0.09159
# ...                                     ...             ...            ...
# O=C1CCc2ncc(Br)cc2N1              2283.2781         0.01833        0.08334
# O=C(O)c1nc(Br)cs1                 2223.5756         0.01968         0.1192
# COC(=O)c1cnc2[nH]cc(Br)c2c1     2485.693371        0.019735        0.09782
# FC(F)(F)c1cc2ccc(Br)cc2cn1        2201.6786         0.01802        0.08641
# O=c1cc(O)c2ccc(Br)cc2o1         2191.142049        0.018092       0.090083
#
#                               Br1_NPA_core  Br1_VBur
# CCOc1ccc(F)c(B(O)O)c1Br          27.999009  0.475556
# OB(O)c1ccc(Br)s1                  27.99896  0.369651
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C     27.99911  0.374921
# C#Cc1ccc(Br)cc1                    27.9991  0.375393
# C#Cc1ccccc1Br                     27.99906  0.402297
# ...                                    ...       ...
# O=C1CCc2ncc(Br)cc2N1              27.99909  0.374685
# O=C(O)c1nc(Br)cs1                   27.999  0.363436
# COC(=O)c1cnc2[nH]cc(Br)c2c1         27.999  0.373893
# FC(F)(F)c1cc2ccc(Br)cc2cn1        27.99909  0.377281
# O=c1cc(O)c2ccc(Br)cc2o1           27.99909  0.376964
#
# [381 rows x 33 columns]

# %%
# map the yields
df_labels = pd.read_csv("./../../xec_raw_dset_bromide_scope.csv",index_col=0,header=0)
df_labels.set_index("ArX_Smiles",inplace=True)
df_labels.index = [Chem.MolToSmiles(Chem.MolFromSmiles(smiles),canonical=True) for smiles in df_labels.index]
df_processed.index = [Chem.MolToSmiles(Chem.MolFromSmiles(smiles),canonical=True) for smiles in df_processed.index]

df_processed["yield"] = df_processed.index.map(df_labels["CAD Yield"])

# %%
# check that all yields were assigned
df_processed[df_processed["yield"].isna()]
# Out:
#                      E  ES_root_dipole  ES_root_electronic_spatial_extent  \
# Brc1cscn1 -3139.649994           2.913                          1160.4273
#
#            ES_root_molar_volume  E_thermal_correction  dipole  \
# Brc1cscn1               679.615              0.050946  2.4799
#
#            electronegativity  hardness  homo_energy  lumo_energy  ...  \
# Brc1cscn1           0.147265  0.107525     -0.25479     -0.03974  ...
#
#            Br1_ES_root_NPA_Rydberg  Br1_ES_root_NPA_core Br1_Mulliken_charge  \
# Brc1cscn1                  0.01915              27.99873           -0.064025
#
#           Br1_NMR_anisotropy Br1_NMR_shift Br1_NPA_Rydberg Br1_NPA_charge  \
# Brc1cscn1          1082.4151     2239.8811          0.0196        0.10187
#
#           Br1_NPA_core  Br1_VBur yield
# Brc1cscn1     27.99901  0.362807   NaN
#
# [1 rows x 34 columns]

# %%
# This is the compound for which the isotope label was manually removed. manually assign the yield
deut_smiles = Chem.MolToSmiles(Chem.MolFromSmiles("[2H]c1nc(cs1)Br"),canonical=True)
df_processed.loc["Brc1cscn1","yield"] = df_labels.loc[deut_smiles,"CAD Yield"]
print(f'Now, there are {len(df_processed[df_processed["yield"].isna()])} compounds without an assigned yield.')
# Out:
# Now, there are 0 compounds without an assigned yield.

# %%
# Save the dataset
df_processed.to_csv("./../xec_dft_data_bromide_scope.csv",index=True,header=True)

# %% [markdown]
# Also generate the pruned dataset

# %%
df_labels = pd.read_csv("./../../xec_raw_dset_bromide_scope_pruned.csv",index_col=0,header=0)
df_labels.set_index("ArX_Smiles",inplace=True)
df_labels.index = [Chem.MolToSmiles(Chem.MolFromSmiles(smiles),canonical=True) for smiles in df_labels.index]
df_combined.index = [Chem.MolToSmiles(Chem.MolFromSmiles(smiles),canonical=True) for smiles in df_combined.index]

df_combined = df_combined.loc[df_combined.index.isin(df_labels.index.to_list())]
print("Remaining substrates in the search space:", len(df_combined))
# Out:
# Remaining substrates in the search space: 258

# %%
df_processed_pruned = feature_preprocessing(df_combined)
df_processed_pruned
# Out:
# The following features were removed: ['charge', 'E_scf', 'E_zpe', 'G', 'G_thermal_correction', 'H', 'H_thermal_correction', 'electronic_spatial_extent', 'number_of_atoms', 'zero_point_correction', 'C1_ES_root_NPA_total', 'C1_ES_root_NPA_valence', 'C1_Mulliken_charge', 'C1_NPA_core', 'C1_NPA_total', 'C1_NPA_valence', 'Br1_ES_root_NPA_charge', 'Br1_ES_root_NPA_total', 'Br1_ES_root_NPA_valence', 'Br1_NPA_total', 'Br1_NPA_valence']
#                                               E  ES_root_dipole  \
# CCOc1ccc(F)c(B(O)O)c1Br            -3231.540851        3.507500
# OB(O)c1ccc(Br)s1                   -3299.457693        2.139700
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C      -3213.049261        2.239700
# C#Cc1ccc(Br)cc1                    -2878.927637        1.453400
# C=CCc1ccc(Br)c(F)c1                -3018.580396        1.392737
# ...                                         ...             ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1 -3398.669046        3.184877
# Cc1cn2cc(F)cc(Br)c2n1              -3088.759492        4.768500
# O=C1CCc2ncc(Br)cc2N1               -3064.781081        0.821700
# FC(F)(F)c1cc2ccc(Br)cc2cn1         -3309.171551        5.377200
# O=c1cc(O)c2ccc(Br)cc2o1            -3142.569127        3.789804
#
#                                     ES_root_electronic_spatial_extent  \
# CCOc1ccc(F)c(B(O)O)c1Br                                   3630.151850
# OB(O)c1ccc(Br)s1                                          2593.089900
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                             7563.164000
# C#Cc1ccc(Br)cc1                                           2237.101700
# C=CCc1ccc(Br)c(F)c1                                       3174.053561
# ...                                                               ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1                       10137.509207
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1    -0.007671  ...
# Cc1cn2cc(F)cc(Br)c2n1                 -0.046940  ...
# O=C1CCc2ncc(Br)cc2N1                  -0.040330  ...
# FC(F)(F)c1cc2ccc(Br)cc2cn1            -0.074800  ...
# O=c1cc(O)c2ccc(Br)cc2o1               -0.066573  ...
#
#                                     Br1_ES_root_Mulliken_charge  \
# CCOc1ccc(F)c(B(O)O)c1Br                               -0.021834
# OB(O)c1ccc(Br)s1                                       0.086668
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                         -0.059843
# C#Cc1ccc(Br)cc1                                        -0.04278
# C=CCc1ccc(Br)c(F)c1                                     0.00069
# ...                                                         ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1                    -0.019984
# Cc1cn2cc(F)cc(Br)c2n1                                 -0.088094
# O=C1CCc2ncc(Br)cc2N1                                   -0.06787
# FC(F)(F)c1cc2ccc(Br)cc2cn1                             0.031004
# O=c1cc(O)c2ccc(Br)cc2o1                               -0.059339
#
#                                     Br1_ES_root_NPA_Rydberg  \
# CCOc1ccc(F)c(B(O)O)c1Br                            0.020462
# OB(O)c1ccc(Br)s1                                    0.02459
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                       0.01919
# C#Cc1ccc(Br)cc1                                     0.01881
# C=CCc1ccc(Br)c(F)c1                                0.020571
# ...                                                     ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1                 0.018624
# Cc1cn2cc(F)cc(Br)c2n1                               0.02148
# O=C1CCc2ncc(Br)cc2N1                                0.01989
# FC(F)(F)c1cc2ccc(Br)cc2cn1                          0.01792
# O=c1cc(O)c2ccc(Br)cc2o1                            0.019713
#
#                                    Br1_ES_root_NPA_core Br1_Mulliken_charge  \
# CCOc1ccc(F)c(B(O)O)c1Br                       27.998934           -0.086074
# OB(O)c1ccc(Br)s1                               27.99881           -0.044191
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C                  27.99905           -0.110674
# C#Cc1ccc(Br)cc1                                27.99902           -0.100266
# C=CCc1ccc(Br)c(F)c1                            27.99897           -0.080558
# ...                                                 ...                 ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1            27.998986           -0.117857
# Cc1cn2cc(F)cc(Br)c2n1                          27.99904           -0.045783
# O=C1CCc2ncc(Br)cc2N1                           27.99903           -0.090537
# FC(F)(F)c1cc2ccc(Br)cc2cn1                     27.99897           -0.084894
# O=c1cc(O)c2ccc(Br)cc2o1                        27.99905           -0.082459
#
#                                    Br1_NMR_anisotropy Br1_NMR_shift  \
# CCOc1ccc(F)c(B(O)O)c1Br                    765.158775   2312.589798
# OB(O)c1ccc(Br)s1                             948.7559     2269.7402
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C               1074.2565     2216.7303
# C#Cc1ccc(Br)cc1                             1065.2392     2212.6936
# C=CCc1ccc(Br)c(F)c1                        828.768086   2361.732075
# ...                                               ...           ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1        1073.395062   2251.919513
# Cc1cn2cc(F)cc(Br)c2n1                        877.1748      2285.202
# O=C1CCc2ncc(Br)cc2N1                        1000.2284     2283.2781
# FC(F)(F)c1cc2ccc(Br)cc2cn1                  1087.1564     2201.6786
# O=c1cc(O)c2ccc(Br)cc2o1                   1070.058017   2191.142049
#
#                                    Br1_NPA_Rydberg Br1_NPA_charge  \
# CCOc1ccc(F)c(B(O)O)c1Br                    0.01855       0.084334
# OB(O)c1ccc(Br)s1                           0.02098        0.13192
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C              0.01778        0.06333
# C#Cc1ccc(Br)cc1                            0.01802        0.07411
# C=CCc1ccc(Br)c(F)c1                       0.019085       0.091399
# ...                                            ...            ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1        0.017846        0.05766
# Cc1cn2cc(F)cc(Br)c2n1                      0.01907        0.12723
# O=C1CCc2ncc(Br)cc2N1                       0.01833        0.08334
# FC(F)(F)c1cc2ccc(Br)cc2cn1                 0.01802        0.08641
# O=c1cc(O)c2ccc(Br)cc2o1                   0.018092       0.090083
#
#                                    Br1_NPA_core  Br1_VBur
# CCOc1ccc(F)c(B(O)O)c1Br               27.999009  0.475556
# OB(O)c1ccc(Br)s1                       27.99896  0.369651
# CC1(C)OB(c2ccc(Br)cc2)OC1(C)C          27.99911  0.374921
# C#Cc1ccc(Br)cc1                         27.9991  0.375393
# C=CCc1ccc(Br)c(F)c1                    27.99907  0.388583
# ...                                         ...       ...
# CC(C)(C)OC(=O)N1CCCCC1c1ccc(Br)cc1     27.99911  0.376253
# Cc1cn2cc(F)cc(Br)c2n1                  27.99902  0.385935
# O=C1CCc2ncc(Br)cc2N1                   27.99909  0.374685
# FC(F)(F)c1cc2ccc(Br)cc2cn1             27.99909  0.377281
# O=c1cc(O)c2ccc(Br)cc2o1                27.99909  0.376964
#
# [258 rows x 33 columns]

# %%
# map the yields
df_processed_pruned["yield"] = df_processed_pruned.index.map(df_labels["CAD Yield"])

# %%
# check that all yields were assigned
df_processed_pruned[df_processed_pruned["yield"].isna()]
# Out:
# Empty DataFrame
# Columns: [E, ES_root_dipole, ES_root_electronic_spatial_extent, ES_root_molar_volume, E_thermal_correction, dipole, electronegativity, hardness, homo_energy, lumo_energy, molar_mass, molar_volume, C1_APT_charge, C1_ES_root_Mulliken_charge, C1_ES_root_NPA_Rydberg, C1_ES_root_NPA_charge, C1_ES_root_NPA_core, C1_NMR_anisotropy, C1_NMR_shift, C1_NPA_Rydberg, C1_NPA_charge, C1_VBur, Br1_APT_charge, Br1_ES_root_Mulliken_charge, Br1_ES_root_NPA_Rydberg, Br1_ES_root_NPA_core, Br1_Mulliken_charge, Br1_NMR_anisotropy, Br1_NMR_shift, Br1_NPA_Rydberg, Br1_NPA_charge, Br1_NPA_core, Br1_VBur, yield]
# Index: []
#
# [0 rows x 34 columns]

# %%
# Save the dataset
df_processed_pruned.to_csv("./../xec_dft_data_bromide_scope_pruned.csv",index=True,header=True)
