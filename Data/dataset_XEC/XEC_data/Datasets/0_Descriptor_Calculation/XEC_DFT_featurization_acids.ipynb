# %% [markdown]
# ### Use the published autochem workflow to generate DFT features for the compounds in the dataset

# %% [markdown]
# NOTE: This notebook needs to be run with the python environment for autoqchem.

# %%
from autoqchem.molecule import molecule
from autoqchem.sge_manager import sge_manager
from autoqchem.draw_utils import draw
from autoqchem.db_functions import descriptors
from rdkit import Chem
import pandas as pd
import logging
logging.basicConfig(level=logging.INFO)

# %%
# connect to UCLA's computation cluster
sm = sge_manager(user='XXXX', host='hoffman2.idre.ucla.edu')
sm.connect()

# %% [markdown]
# ### Load the product smiles strings and create input files for the DFT calculations

# %%
# Load the previously saved list of reaction products
df_smiles = pd.read_csv("./xec_smiles_acid_scope_subs.csv",header=0)
df_smiles
# Out:
#                                                      0
# 0           COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23
# 1             CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2
# 2    CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C...
# 3                                          O=C(O)C1CC1
# 4                            O=C(O)C1(c2ccc(Cl)cc2)CC1
# ..                                                 ...
# 382                            Cn1ncc2ccc(CC(=O)O)cc21
# 383          C[C@@H]1CC[C@H](C(=O)O)CN1C(=O)OCc1ccccc1
# 384              COC(=O)C1CN(C(=O)OC(C)(C)C)CCC1C(=O)O
# 385         CC(C)(C)OC(=O)N1CC2(C1)CS(=O)(=O)CC2C(=O)O
# 386    O=C(O)CC1CCC2(CC1)CCN(c1cc(OC(F)(F)F)ccc1Cl)CC2
#
# [387 rows x 1 columns]

# %%
smiles_list = df_smiles.iloc[:,0]
len(smiles_list)
# Out:
# 387

# %%
# generate molecule objects with up to 8 conformers for each structure
mols = [molecule(s, num_conf=8) for s in product_smiles]

# %%
# check the compounds by drawing them
draw(mols[29].mol)
# Out:
# interactive(children=(Dropdown(description='confId', options=(0, 1, 2, 3, 4, 5, 6, 7), value=0), Output()), _d…
# <function autoqchem.draw_utils._graph_conf(m, confId=0, energies=[])>

# %%
# create Gaussian jobs locally
for mol in mols:
    sm.create_jobs_for_molecule(mol, theory="APFD",heavy_basis_set="def2tzvp",light_basis_set='def2svp',max_light_atomic_number=10)

# %% [markdown]
# ### Manage the DFT jobs on the cluster

# %%
# Submit jobs
sm.submit_jobs()
# Out:
# INFO:autoqchem.sge_manager:Submitting 5115 jobs.
#   0%|          | 0/5115 [00:00<?, ?it/s]INFO:paramiko.transport.sftp:[chan 1] Opened sftp connection (server version 3)
# INFO:autoqchem.sge_manager:Submitted job 452c8236418da918c5e6b3c51f99c5d2, job_id: 10194892.
#   0%|          | 1/5115 [00:03<4:42:42,  3.32s/it]INFO:autoqchem.sge_manager:Submitted job 293b20cd44ba9349caae40bd75260026, job_id: 10194893.
#   0%|          | 2/5115 [00:05<3:32:38,  2.50s/it]INFO:autoqchem.sge_manager:Submitted job d8f63b99afdf9636fc44bfa92ac364b9, job_id: 10194894.
#   0%|          | 3/5115 [00:07<3:08:39,  2.21s/it]INFO:autoqchem.sge_manager:Submitted job 33048eb2e10feb11eb536b24f45824d8, job_id: 10194895.
#   0%|          | 4/5115 [00:08<2:52:14,  2.02s/it]INFO:autoqchem.sge_manager:Submitted job 72023b64bf749bfe087be399681012b4, job_id: 10194896.
#   0%|          | 5/5115 [00:10<2:40:28,  1.88s/it]INFO:autoqchem.sge_manager:Submitted job 4849e6bc554f46516b08bee21d18c13e, job_id: 10194897.
#   0%|          | 6/5115 [00:12<2:36:40,  1.84s/it]INFO:autoqchem.sge_manager:Submitted job d54012b83c6106ddcc26a50ab9ae04fe, job_id: 10194898.
#   0%|          | 7/5115 [00:15<3:10:58,  2.24s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Submit jobs
# ----> 2 sm.submit_jobs()
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/autoqchem/sge_manager.py:165, in sge_manager.submit_jobs(self)
#     163 jobs = self.get_jobs(sge_status.created)
#     164 logger.info(f"Submitting {len(jobs)} jobs.")
# --> 165 self.submit_jobs_from_jobs_dict(jobs)
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/autoqchem/sge_manager.py:186, in sge_manager.submit_jobs_from_jobs_dict(self, jobs)
#     183 self.connection.put(f"{job.directory}/{job.base_name}.gjf", self.remote_dir)
#     185 with self.connection.cd(self.remote_dir):
# --> 186     ret = self.connection.run(f"qsub {self.remote_dir}/{job.base_name}.sh", hide=True)
#     187     job.job_id = re.search(".*job\s*(\d+)\s*[(].*\n", ret.stdout).group(1)
#     188     job.status = sge_status.submitted
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/fabric/connection.py:23, in opens(method, self, *args, **kwargs)
#      20 @decorator
#      21 def opens(method, self, *args, **kwargs):
#      22     self.open()
# ---> 23     return method(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/fabric/connection.py:763, in Connection.run(self, command, **kwargs)
#     748 @opens
#     749 def run(self, command, **kwargs):
#     750     """
#     751     Execute a shell command on the remote end of this connection.
#     752
#    (...)
#     761     .. versionadded:: 2.0
#     762     """
# --> 763     return self._run(self._remote_runner(), command, **kwargs)
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/invoke/context.py:113, in Context._run(self, runner, command, **kwargs)
#     109 def _run(
#     110     self, runner: "Runner", command: str, **kwargs: Any
#     111 ) -> Optional[Result]:
#     112     command = self._prefix_commands(command)
# --> 113     return runner.run(command, **kwargs)
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/fabric/runners.py:83, in Remote.run(self, command, **kwargs)
#      81 def run(self, command, **kwargs):
#      82     kwargs.setdefault("replace_env", True)
# ---> 83     return super().run(command, **kwargs)
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/invoke/runners.py:395, in Runner.run(self, command, **kwargs)
#     126 """
#     127 Execute ``command``, returning an instance of `Result` once complete.
#     128
#    (...)
#     392 .. versionadded:: 1.0
#     393 """
#     394 try:
# --> 395     return self._run_body(command, **kwargs)
#     396 finally:
#     397     if not (self._asynchronous or self._disowned):
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/invoke/runners.py:451, in Runner._run_body(self, command, **kwargs)
#     449     thread.start()
#     450 # Wrap up or promise that we will, depending
# --> 451 return self.make_promise() if self._asynchronous else self._finish()
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/invoke/runners.py:473, in Runner._finish(self)
#     468         # Don't locally stop on ^C, only forward it:
#     469         # - if remote end really stops, we'll naturally stop after
#     470         # - if remote end does not stop (eg REPL, editor) we don't want
#     471         # to stop prematurely
#     472         except KeyboardInterrupt as e:
# --> 473             self.send_interrupt(e)
#     474         # TODO: honor other signals sent to our own process and
#     475         # transmit them to the subprocess before handling 'normally'.
#     476 # Make sure we tie off our worker threads, even if something exploded.
#    (...)
#     479 finally:
#     480     # Inform stdin-mirroring worker to stop its eternal looping
#     481     self.program_finished.set()
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/fabric/runners.py:115, in Remote.send_interrupt(self, interrupt)
#     113     self.channel.send("\x03")
#     114 else:
# --> 115     raise interrupt
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/invoke/runners.py:466, in Runner._finish(self)
#     464 while True:
#     465     try:
# --> 466         self.wait()
#     467         break  # done waiting!
#     468     # Don't locally stop on ^C, only forward it:
#     469     # - if remote end really stops, we'll naturally stop after
#     470     # - if remote end does not stop (eg REPL, editor) we don't want
#     471     # to stop prematurely
#
# File /opt/miniconda3/envs/autoqchem/lib/python3.8/site-packages/invoke/runners.py:1003, in Runner.wait(self)
#    1001 if proc_finished or dead_threads:
#    1002     break
# -> 1003 time.sleep(self.input_sleep)
#
# KeyboardInterrupt:

# %%
# Resubmit jobs that did not finish properly
sm.resubmit_incomplete_jobs()
# Out:
# INFO:autoqchem.sge_manager:Resubmitting failed jobs:
#   0%|          | 0/17 [00:00<?, ?it/s]INFO:autoqchem.sge_manager:Submitted job 78d18a1699498c04fc6e7aebd69e9982, job_id: 10092196.
#   6%|▌         | 1/17 [00:02<00:41,  2.58s/it]INFO:autoqchem.sge_manager:Submitted job f4ff46dcd99ac9db16e9b09ec57b69a1, job_id: 10092197.
#  12%|█▏        | 2/17 [00:04<00:30,  2.04s/it]INFO:autoqchem.sge_manager:Submitted job 1b6d9e07fe92efcdc980bdbe731011c7, job_id: 10092198.
#  18%|█▊        | 3/17 [00:05<00:26,  1.89s/it]INFO:autoqchem.sge_manager:Submitted job 5810cdfd89c0b027fe3af3348c3e27d3, job_id: 10092199.
#  24%|██▎       | 4/17 [00:07<00:23,  1.84s/it]INFO:autoqchem.sge_manager:Submitted job 597073b107ba683cc30247887b5574c7, job_id: 10092200.
#  29%|██▉       | 5/17 [00:09<00:21,  1.78s/it]INFO:autoqchem.sge_manager:Submitted job b3ca31108e6e1762d2b98c63e49669de, job_id: 10092201.
#  35%|███▌      | 6/17 [00:11<00:19,  1.75s/it]INFO:autoqchem.sge_manager:Submitted job f83834be5fbd30397ba197ac6465f675, job_id: 10092202.
#  41%|████      | 7/17 [00:12<00:17,  1.75s/it]INFO:autoqchem.sge_manager:Submitted job 6e4b2c49917283fdbc18b9e1c7fd18fb, job_id: 10092203.
#  47%|████▋     | 8/17 [00:14<00:15,  1.75s/it]INFO:autoqchem.sge_manager:Submitted job 91c4e55e4cbfd6ee7b06e3d7711f00cf, job_id: 10092204.
#  53%|█████▎    | 9/17 [00:16<00:13,  1.74s/it]INFO:autoqchem.sge_manager:Submitted job 0153e18fcd119066f6bd2871254990ad, job_id: 10092207.
#  59%|█████▉    | 10/17 [00:19<00:15,  2.25s/it]INFO:autoqchem.sge_manager:Submitted job ee4106f07421162b3ca4423283749be1, job_id: 10092210.
#  65%|██████▍   | 11/17 [00:21<00:13,  2.19s/it]INFO:autoqchem.sge_manager:Submitted job ff8be3b2627a01d05b1cfe1bf61c7eb9, job_id: 10092213.
#  71%|███████   | 12/17 [00:23<00:10,  2.04s/it]INFO:autoqchem.sge_manager:Submitted job aa2918207ee20f9caefb9c5241b1836a, job_id: 10092216.
#  76%|███████▋  | 13/17 [00:25<00:07,  1.93s/it]INFO:autoqchem.sge_manager:Submitted job acb1d237402a040391309478920038b2, job_id: 10092219.
#  82%|████████▏ | 14/17 [00:26<00:05,  1.87s/it]INFO:autoqchem.sge_manager:Submitted job 4fdfc3209da426ebaca7aa7c4437f5dc, job_id: 10092222.
#  88%|████████▊ | 15/17 [00:28<00:03,  1.83s/it]INFO:autoqchem.sge_manager:Submitted job 9be18e174ec0f85fc8ce831fc3eb82e0, job_id: 10092225.
#  94%|█████████▍| 16/17 [00:30<00:01,  1.79s/it]INFO:autoqchem.sge_manager:Submitted job 2e0c83579c6455251b5f30a443267f4f, job_id: 10092228.
# 100%|██████████| 17/17 [00:31<00:00,  1.88s/it]
# INFO:autoqchem.sge_manager:Resubmitting incomplete jobs:
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
# INFO:autoqchem.sge_manager:Substituting last checked geometry in the new input file.
# INFO:autoqchem.sge_manager:Substituting wall_time with new value: 23:59:00
#   0%|          | 0/10 [00:00<?, ?it/s]INFO:autoqchem.sge_manager:Submitted job dfda3e3d33b63d68775376825097424f, job_id: 10092231.
#  10%|█         | 1/10 [00:01<00:15,  1.71s/it]INFO:autoqchem.sge_manager:Submitted job 2a4731f1a13c73db068fd1505dbf228a, job_id: 10092235.
#  20%|██        | 2/10 [00:03<00:14,  1.79s/it]INFO:autoqchem.sge_manager:Submitted job 5df90324e9064c3a8d481aecbe097ac9, job_id: 10092238.
#  30%|███       | 3/10 [00:05<00:12,  1.81s/it]INFO:autoqchem.sge_manager:Submitted job 70926ef1337b87aa7cb25de8e841c12a, job_id: 10092241.
#  40%|████      | 4/10 [00:07<00:10,  1.80s/it]INFO:autoqchem.sge_manager:Submitted job 1cfac23491a6bccf9c56c4f12395ab93, job_id: 10092244.
#  50%|█████     | 5/10 [00:08<00:08,  1.80s/it]INFO:autoqchem.sge_manager:Submitted job 11d53eeecd0ab33448d3a60c224bbc2e, job_id: 10092247.
#  60%|██████    | 6/10 [00:10<00:07,  1.78s/it]INFO:autoqchem.sge_manager:Submitted job 64bc9085e0f3167692de89db6dec046d, job_id: 10092250.
#  70%|███████   | 7/10 [00:12<00:05,  1.77s/it]INFO:autoqchem.sge_manager:Submitted job d2d79df5aa737bafb6c9b5099aace788, job_id: 10092254.
#  80%|████████  | 8/10 [00:14<00:03,  1.76s/it]INFO:autoqchem.sge_manager:Submitted job ed731a0212c1e1ab540dfa1fbafe85fd, job_id: 10092257.
#  90%|█████████ | 9/10 [00:16<00:01,  1.78s/it]INFO:autoqchem.sge_manager:Submitted job c76f79dd82f44b600a2f5596b2681620, job_id: 10092261.
# 100%|██████████| 10/10 [00:17<00:00,  1.78s/it]

# %%
# Retrieve finished jobs from the cluster
sm.retrieve_jobs()

# %%
# Upload data for finished compounds to the autoqchem database (autoqchem.org)
sm.upload_done_molecules_to_db(tags=["SVR_MacMillanXEC"])

# %% [markdown]
# ### Get the desriptors from the autoqchem database

# %% [markdown]
# first get the 3 bromides

# %%
# Download the descriptors
data = descriptors(tags=["SVR_MacMillanXEC"],presets=["global","substructure"],conf_option="boltzmann",solvent="None",
                   functional="APFD",basis_set="def2svp",substructure="cBr")

# %%
# Process the data so that it is in one dataframe
label_dict={}
for key in data:
    if key != "global":
        # atom descriptor dataframes are by default called atom1, atom2, etc. --> replace with the atom type and a running number (e. g. "C1" and "C2")
        if data[key].iloc[0,-1] not in label_dict:
            label_dict[data[key].iloc[0,-1]] = 1
        else:
            label_dict[data[key].iloc[0,-1]] += 1
        label = data[key].iloc[0,-1]+str(label_dict[data[key].iloc[0,-1]])
        data[key].drop(columns=["labels","X","Y","Z"],inplace=True)
        data[key].columns = [f"{label}_{column}" for column in data[key].columns]
    else:
        data[key].drop(columns=["converged","multiplicity"],inplace=True)

df_bromide = pd.concat(data,axis=1)
df_bromide.columns = [multi_column_index[1] for multi_column_index in df_bromide.columns]

# %%
df_bromide
# Out:
#                                                               E  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2           -3542.222451
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)... -3943.891919
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23         -3524.070081
#
#                                                     ES_root_dipole  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                  7.456172
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...        6.507722
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                6.885499
#
#                                                     ES_root_electronic_spatial_extent  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                                 11392.143394
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...                       12911.462626
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                                6901.164734
#
#                                                     ES_root_molar_volume  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                     2262.849124
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...           2613.668236
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                   2329.619286
#
#                                                           E_scf  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2           -3542.511141
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)... -3944.244652
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23         -3524.339370
#
#                                                     E_thermal_correction  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                        0.297904
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...              0.367085
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                      0.279476
#
#                                                           E_zpe            G  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2           -3542.242007 -3542.292264
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)... -3943.915688 -3943.971596
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23         -3524.088138 -3524.135520
#
#                                                     G_thermal_correction  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                        0.228092
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...              0.287409
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                      0.214037
#
#                                                               H  ...  \
# can                                                              ...
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2           -3542.221507  ...
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)... -3943.890975  ...
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23         -3524.069137  ...
#
#                                                     Br1_ES_root_NPA_valence  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                           6.898692
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...                 6.906679
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                         6.861579
#
#                                                     Br1_Mulliken_charge  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                      -0.155115
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...            -0.170085
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                    -0.175634
#
#                                                     Br1_NMR_anisotropy  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                   1243.325483
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...         1166.646775
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                 1255.934604
#
#                                                     Br1_NMR_shift  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2              2063.919134
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...     2162.33304
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23            2095.646495
#
#                                                     Br1_NPA_Rydberg  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                    0.02425
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...         0.025172
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                  0.02451
#
#                                                     Br1_NPA_charge  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                  0.081892
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...          0.0834
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                0.067722
#
#                                                     Br1_NPA_core  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                27.99911
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...      27.99906
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23              27.99911
#
#                                                     Br1_NPA_total  \
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                34.918108
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...        34.9166
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23              34.932278
#
#                                                     Br1_NPA_valence  Br1_VBur
# can
# CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(Br)ccc1-2                   6.894753  0.375827
# CN1C(=O)C[C@@](C)(c2cc(Br)cs2)N/C1=N/C(=O)OC(C)...         6.892359  0.368236
# COC(=O)CC1CCc2cc(Br)cc3[nH]c(=O)c(=O)n1c23                 6.908648  0.376023
#
# [3 rows x 54 columns]

# %%
# Save the data
df_bromide.to_csv("./../1_Dataset_Generation/Data_For_Individual_Substrates/xec_dft_descr_bromides.csv",index=True,header=True)

# %% [markdown]
# same thing for the acids

# %%
# Download the descriptors
data = descriptors(tags=["SVR_MacMillanXEC"],presets=["global","substructure"],conf_option="boltzmann",solvent="None",
                   functional="APFD",basis_set="def2svp",substructure="[c,C]C(=O)[OH]")
# Process the data so that it is in one dataframe
label_dict={}
for key in data:
    if key != "global":
        # atom descriptor dataframes are by default called atom1, atom2, etc. --> replace with the atom type and a running number (e. g. "C1" and "C2")
        if data[key].iloc[0,-1] not in label_dict:
            label_dict[data[key].iloc[0,-1]] = 1
        else:
            label_dict[data[key].iloc[0,-1]] += 1
        label = data[key].iloc[0,-1]+str(label_dict[data[key].iloc[0,-1]])
        data[key].drop(columns=["labels","X","Y","Z"],inplace=True)
        data[key].columns = [f"{label}_{column}" for column in data[key].columns]
    else:
        data[key].drop(columns=["converged","multiplicity"],inplace=True)

df_acid = pd.concat(data,axis=1)
df_acid.columns = [multi_column_index[1] for multi_column_index in df_acid.columns]
df_acid
# Out:
#                                                               E  \
# can
# C#CCCCCCCC(=O)O                                     -500.798988
# C=C1C[C@]23C[C@@]1(O)CC[C@H]2[C@@]12C=C[C@H](O)... -1186.441955
# C=CC[C@H](CC(=O)O)NC(=O)OC(C)(C)C                   -784.799817
# C=C[C@@H]1C[C@]1(NC(=O)OC(C)(C)C)C(=O)O             -783.592022
# CC(=O)CC(C(=O)O)c1ccccc1                            -650.882866
# ...                                                         ...
# O=C1CC(C(=O)O)CCN1                                  -513.585362
# O=C1CCC(C(=O)O)CC1                                  -497.539858
# O=C1CCC(C(=O)O)Cc2ccccc21                           -688.932575
# O=C1O[C@]2(CC[C@H](C(=O)O)CC2)c2cnccc21             -857.347135
# O=Cc1cccc(OCC(=O)O)c1                               -647.511219
#
#                                                     ES_root_dipole  \
# can
# C#CCCCCCCC(=O)O                                           0.761858
# C=C1C[C@]23C[C@@]1(O)CC[C@H]2[C@@]12C=C[C@H](O)...        3.265400
# C=CC[C@H](CC(=O)O)NC(=O)OC(C)(C)C                         2.130126
# C=C[C@@H]1C[C@]1(NC(=O)OC(C)(C)C)C(=O)O                   3.448019
# C=C[C@@H]1C[C@]1(NC(=O)OC(C)(C)C)C(=O)O                   6.693457  0.433593
# CC(=O)CC(C(=O)O)c1ccccc1                                  6.681905  0.404615
# ...                                                            ...       ...
# O=C1CC(C(=O)O)CCN1                                        6.696811  0.393586
# O=C1CCC(C(=O)O)CC1                                        6.698206   0.40774
# O=C1CCC(C(=O)O)Cc2ccccc21                                 6.697287  0.400356
# O=C1O[C@]2(CC[C@H](C(=O)O)CC2)c2cnccc21                   6.697984  0.395898
# O=Cc1cccc(OCC(=O)O)c1                                     6.687889  0.406222
#
# [380 rows x 86 columns]

# %% [markdown]
# Please note that four acid substrates were already calculated in the dataset "SVR_Amide" with the same calculation settings and therefore not recalculated as part of this dataset.

# %%
# Find the missing acids
acid_smiles_incomplete = df_acid.index.tolist()
bromide_smiles = df_bromide.index.tolist()
acid_smiles_missing = [smiles for smiles in smiles_list]  # smiles_list contains all substrates (acids and bromides)
for smiles in smiles_list:
    if (smiles in acid_smiles_incomplete) or (smiles in bromide_smiles):
        acid_smiles_missing.remove(smiles)
print("Missing compounds that were already calculated for the dataset 'SVR_Amide':")
acid_smiles_missing
# Out:
# Missing compounds that were already calculated for the dataset 'SVR_Amide':
# ['COc1ccc(CC(=O)O)cc1',
#  'O=C(O)Cc1ccc(C(F)(F)F)cc1',
#  'CC1(C)C(C(=O)O)C1(C)C',
#  'O=C(O)C1CCC(F)(F)CC1']

# %%
# download the descriptors for the missing acids
data_missing = descriptors(tags=["SVR_Amide"],presets=["global","substructure"],conf_option="boltzmann",solvent="None",
                   functional="APFD",basis_set="def2svp",substructure="[c,C]C(=O)[OH]")
# Process the data so that it is in one dataframe
label_dict={}
for key in data_missing:
    if key != "global":
        # atom descriptor dataframes are by default called atom1, atom2, etc. --> replace with the atom type and a running number (e. g. "C1" and "C2")
        if data_missing[key].iloc[0,-1] not in label_dict:
            label_dict[data_missing[key].iloc[0,-1]] = 1
        else:
            label_dict[data_missing[key].iloc[0,-1]] += 1
        label = data_missing[key].iloc[0,-1]+str(label_dict[data_missing[key].iloc[0,-1]])
        data_missing[key].drop(columns=["labels","X","Y","Z"],inplace=True)
        data_missing[key].columns = [f"{label}_{column}" for column in data_missing[key].columns]
    else:
        data_missing[key].drop(columns=["converged","multiplicity"],inplace=True)

df_missing = pd.concat(data_missing,axis=1)
df_missing.columns = [multi_column_index[1] for multi_column_index in df_missing.columns]

# only keep the missing acids
df_missing = df_missing.loc[df_missing.index.isin(acid_smiles_missing)]
df_missing
# Out:
#                                     E  ES_root_dipole  \
# can
# CC1(C)C(C(=O)O)C1(C)C     -462.817211        0.512000
# COc1ccc(CC(=O)O)cc1       -573.597364        3.153495
# O=C(O)C1CCC(F)(F)CC1      -621.840309        2.635259
# O=C(O)Cc1ccc(C(F)(F)F)cc1 -795.833904        4.088151
#
#                            ES_root_electronic_spatial_extent  \
# can
# CC1(C)C(C(=O)O)C1(C)C                            1498.425100
# COc1ccc(CC(=O)O)cc1                              2707.380430
# O=C(O)C1CCC(F)(F)CC1                             1918.758346
# O=C(O)Cc1ccc(C(F)(F)F)cc1                        3723.640118
#
#                            ES_root_molar_volume       E_scf  \
# can
# CC1(C)C(C(=O)O)C1(C)C               1353.173000 -463.029059
# COc1ccc(CC(=O)O)cc1                 1506.025079 -573.782225
# O=C(O)C1CCC(F)(F)CC1                1100.191768 -622.018584
# O=C(O)Cc1ccc(C(F)(F)F)cc1           1428.520495 -795.990933
#
#                            E_thermal_correction       E_zpe           G  \
# can
# CC1(C)C(C(=O)O)C1(C)C                  0.221085 -462.828630 -462.864730
# COc1ccc(CC(=O)O)cc1                    0.188370 -573.608446 -573.647751
# O=C(O)C1CCC(F)(F)CC1                   0.180612 -621.850101 -621.886045
# O=C(O)Cc1ccc(C(F)(F)F)cc1              0.162045 -795.845977 -795.888103
#
#                            G_thermal_correction           H  ...  \
# can                                                          ...
# CC1(C)C(C(=O)O)C1(C)C                  0.173566 -462.816266  ...
# COc1ccc(CC(=O)O)cc1                    0.137983 -573.596420  ...
# O=C(O)C1CCC(F)(F)CC1                   0.134876 -621.839365  ...
# O=C(O)Cc1ccc(C(F)(F)F)cc1              0.107846 -795.832960  ...
#
#                            O2_ES_root_NPA_valence  O2_Mulliken_charge  \
# can
# CC1(C)C(C(=O)O)C1(C)C                     6.64311            -0.19892
# COc1ccc(CC(=O)O)cc1                      6.694966           -0.202234
# O=C(O)C1CCC(F)(F)CC1                     6.658938           -0.202033
# O=C(O)Cc1ccc(C(F)(F)F)cc1                6.691862           -0.197326
#
#                            O2_NMR_anisotropy  O2_NMR_shift  O2_NPA_Rydberg  \
# can
# CC1(C)C(C(=O)O)C1(C)C               200.9927      135.3815         0.00993
# COc1ccc(CC(=O)O)cc1               177.250002    145.792822        0.010411
# O=C(O)C1CCC(F)(F)CC1              178.153197    150.492035        0.010197
# O=C(O)Cc1ccc(C(F)(F)F)cc1         180.765052    146.055224          0.0102
#
#                            O2_NPA_charge  O2_NPA_core  O2_NPA_total  \
# can
# CC1(C)C(C(=O)O)C1(C)C           -0.70119       1.9997       8.70119
# COc1ccc(CC(=O)O)cc1            -0.705854     1.999683      8.705854
# O=C(O)C1CCC(F)(F)CC1           -0.711129      1.99968      8.711129
# O=C(O)Cc1ccc(C(F)(F)F)cc1       -0.70358      1.99969       8.70358
#
#                            O2_NPA_valence   O2_VBur
# can
# CC1(C)C(C(=O)O)C1(C)C             6.69157  0.355648
# COc1ccc(CC(=O)O)cc1               6.69576  0.375991
# O=C(O)C1CCC(F)(F)CC1              6.70125  0.398661
# O=C(O)Cc1ccc(C(F)(F)F)cc1        6.693695  0.355745
#
# [4 rows x 86 columns]

# %%
# ensure that the columns are aligned
df_missing_acids = df_missing[df_acid.columns]

# concatenate the dataframes
df_acids_complete = pd.concat([df_missing,df_acid],axis=0)
df_acids_complete.drop(columns="charge",inplace=True)
df_acids_complete
# Out:
#                                                   E  ES_root_dipole  \
# can
# CC1(C)C(C(=O)O)C1(C)C                   -462.817211        0.512000
# COc1ccc(CC(=O)O)cc1                     -573.597364        3.153495
# COc1ccc(CC(=O)O)cc1                     -573.647751              0.137983
# O=C(O)C1CCC(F)(F)CC1                    -621.886045              0.134876
# O=C(O)Cc1ccc(C(F)(F)F)cc1               -795.888103              0.107846
# C#CCCCCCCC(=O)O                         -500.852384              0.174732
# ...                                             ...                   ...
# O=C1CC(C(=O)O)CCN1                      -513.629557              0.121100
# O=C1CCC(C(=O)O)CC1                      -497.584301              0.131505
# O=C1CCC(C(=O)O)Cc2ccccc21               -688.984092              0.181257
# O=C1O[C@]2(CC[C@H](C(=O)O)CC2)c2cnccc21 -857.404382              0.206478
# O=Cc1cccc(OCC(=O)O)c1                   -647.561579              0.119511
#
#                                                   H  ...  \
# can                                                  ...
# CC1(C)C(C(=O)O)C1(C)C                   -462.816266  ...
# COc1ccc(CC(=O)O)cc1                     -573.596420  ...
# O=C(O)C1CCC(F)(F)CC1                    -621.839365  ...
# O=C(O)Cc1ccc(C(F)(F)F)cc1               -795.832960  ...
# C#CCCCCCCC(=O)O                         -500.798044  ...
# ...                                             ...  ...
# O=C1CC(C(=O)O)CCN1                      -513.584418  ...
# O=C1CCC(C(=O)O)CC1                      -497.538914  ...
# O=C1CCC(C(=O)O)Cc2ccccc21               -688.931631  ...
# O=C1O[C@]2(CC[C@H](C(=O)O)CC2)c2cnccc21 -857.346191  ...
# O=Cc1cccc(OCC(=O)O)c1                   -647.510275  ...
#
#                                          O2_ES_root_NPA_valence  \
# can
# CC1(C)C(C(=O)O)C1(C)C                                   6.64311
# COc1ccc(CC(=O)O)cc1                                    6.694966
# O=C(O)C1CCC(F)(F)CC1                                   6.658938
# O=C(O)Cc1ccc(C(F)(F)F)cc1                              6.691862
# C#CCCCCCCC(=O)O                                        6.654414
# ...                                                         ...
# O=C1CC(C(=O)O)CCN1                                     6.713283
# O=C1CCC(C(=O)O)CC1                                     6.698578
# O=C1CCC(C(=O)O)Cc2ccccc21                               6.70012
# O=C1O[C@]2(CC[C@H](C(=O)O)CC2)c2cnccc21                6.698105
# O=Cc1cccc(OCC(=O)O)c1                                  6.686836
#
#                                          O2_Mulliken_charge  \
# can
# CC1(C)C(C(=O)O)C1(C)C                              -0.19892
# COc1ccc(CC(=O)O)cc1                               -0.202234
# O=C(O)C1CCC(F)(F)CC1                              -0.202033
# O=C(O)Cc1ccc(C(F)(F)F)cc1                         -0.197326
# C#CCCCCCCC(=O)O                                   -0.202855
# ...                                                     ...
# O=C1CC(C(=O)O)CCN1                                -0.196779
# O=C1CCC(C(=O)O)CC1                                -0.197578
# O=C1CCC(C(=O)O)Cc2ccccc21                         -0.195811
# O=C1O[C@]2(CC[C@H](C(=O)O)CC2)c2cnccc21           -0.199537
# O=Cc1cccc(OCC(=O)O)c1                             -0.188732
#
#                                          O2_NMR_anisotropy  O2_NMR_shift  \
# can
# CC1(C)C(C(=O)O)C1(C)C                             200.9927      135.3815
# COc1ccc(CC(=O)O)cc1                             177.250002    145.792822
# O=C(O)C1CCC(F)(F)CC1                            178.153197    150.492035
